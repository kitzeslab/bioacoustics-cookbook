# %% [markdown]
# # Use Crowsetta and Opensoundscape to load Audacity-style .txt label files

# %%
from glob import glob
from opensoundscape.annotations import BoxedAnnotations
from pathlib import Path
import crowsetta

# %% [markdown]
# here, we run a loop where we assume each .wav file in the folder has a corresponding .txt file of the same name containing Audacity label format.
#
# (it will skip over files without a matching name)

# %%
scribe = crowsetta.Transcriber(format="aud-bbox")

boxed_anns = []
audio_paths = glob("/path_to_wavs/*.wav")
for audio_p in audio_paths:
    p = audio_p.replace(".wav", ".txt").replace(".mp3", ".txt")
    if not Path(p).exists():
        print(f"{p} does not exist, skipping")
        continue
    a = scribe.from_file(p)
    a.df.low_freq_hz = a.df.low_freq_hz.apply(lambda x: max([0, x]))
    a = a.to_annot()
    a.notated_path = audio_p
    ba = BoxedAnnotations.from_crowsetta(a)
    # specify the list of annotated audio files: in this case, just one file is associated with the annotations
    ba.audio_files = [audio_p]

    # can use ba.to_raven_files() to save to raven files
    # ba.to_raven_files("save/dir/")
    # or ba.clip_labels() to create multi-hot labels for fixed-length audio segments

    # do stuff with your BoxedAnnotations object or append it to a list...
    boxed_anns.append(ba)

# combine all the BoxedAnnotations objects into one
ba = BoxedAnnotations.concat(boxed_anns)
# Out:
# /Users/SML161/hawaii/macaulay_library_samples/audio/Akekee/5045.txt does not exist, skipping

# %% [markdown]
# We now have a BoxedAnnotations object

# %%
ba
# Out:
#                                             audio_file  \
# 0    /Users/SML161/hawaii/macaulay_library_samples/...
# 1    /Users/SML161/hawaii/macaulay_library_samples/...
# 2    /Users/SML161/hawaii/macaulay_library_samples/...
# 3    /Users/SML161/hawaii/macaulay_library_samples/...
# 4    /Users/SML161/hawaii/macaulay_library_samples/...
# ..                                                 ...
# 260  /Users/SML161/hawaii/macaulay_library_samples/...
# 261  /Users/SML161/hawaii/macaulay_library_samples/...
# 262  /Users/SML161/hawaii/macaulay_library_samples/...
# 263  /Users/SML161/hawaii/macaulay_library_samples/...
# 264  /Users/SML161/hawaii/macaulay_library_samples/...
#
#                                        annotation_file annotation  start_time  \
# 0    /Users/SML161/hawaii/macaulay_library_samples/...  AKEK_song    6.853767
# 1    /Users/SML161/hawaii/macaulay_library_samples/...  AKEK_song   21.679547
# 2    /Users/SML161/hawaii/macaulay_library_samples/...  AKEK_song   29.651560
# 3    /Users/SML161/hawaii/macaulay_library_samples/...  AKEK_song   41.555471
# 4    /Users/SML161/hawaii/macaulay_library_samples/...  AKEK_song   49.888209
# ..                                                 ...        ...         ...
# 260  /Users/SML161/hawaii/macaulay_library_samples/...  AKEK_song   55.159169
# 261  /Users/SML161/hawaii/macaulay_library_samples/...   AKE_song   63.604054
# 262  /Users/SML161/hawaii/macaulay_library_samples/...  AKEK_song   67.080531
# 263  /Users/SML161/hawaii/macaulay_library_samples/...      voice   68.347264
# 264  /Users/SML161/hawaii/macaulay_library_samples/...  AKEK_song   72.105237
#
#       end_time        low_f       high_f  annotation_id
# 0     8.404883  2926.829102  6402.438965              0
# 1    24.637489  3048.780518  5975.609863              0
# 2    31.563400  2865.853516  6585.366211              0
# 3    43.160696  3170.731689  6646.341797              0
# 4    51.583614  3231.707275  6585.366211              0
# ..         ...          ...          ...            ...
# 260  61.584319  2743.902588  5548.780762              0
# 261  66.003808  3658.536621  6097.561035              0
# 262  69.395837  3292.683105  6097.561035              0
# 263  71.873003     0.000000  1646.341553              0
# 264  75.342443  3048.780518  6036.585449              0
#
# [265 rows x 8 columns]
